# %% [markdown]
# # Валидация базы знаний 29н
#
# 1. Запустите `python scripts/parse_29n_pdf.py` после добавления `data/29N.pdf`.
# 2. Сверьте `knowledge/rules_raw.json` с `knowledge/contraindication_rules.json`.
# 3. Проверьте покрытие: `python scripts/validate_kb_coverage.py`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.medhack_ai_assistant.expert_pipeline import run_expert_pipeline, infer_single_row
from src.medhack_ai_assistant.config import TRAIN_PATH

train = pd.read_csv(TRAIN_PATH)
row = train[train["exam_row_id"] == 1015330919].iloc[0]
inf, report = infer_single_row(row)
assert inf.contraindicated_factors == {"4.4"}, inf.contraindicated_factors
print(report.summary)
print(report.markdown[:1500])

# %%
result = run_expert_pipeline(evaluate_train=True)
print(result.metrics)
